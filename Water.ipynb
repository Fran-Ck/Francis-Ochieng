# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
Maji = pd.read_csv('/home/franc/Data/Utilities/NairobiWater.csv', skiprows=0)
Maji.head()
print(Maji.dtypes)
# Out:
# Day       object
# Amount    object
# dtype: object

# %%
#Crosschecking the column titles
Maji.columns = ['Month', 'Amount',]
Maji.head()
# Out:
#        Month      Amount
# 0  3/31/2014  267,392.22
# 1  4/30/2014  301,629.76
# 2  7/14/2014  202,242.86
# 3   7/1/2014  258,229.05
# 4  7/31/2014  311,357.83

# %%
#Lets convert the object(month) into a timseries object and use the month as our object.
from datetime import datetime
con=Maji['Month']
Maji['Month']=pd.to_datetime(Maji['Month'])
Maji.set_index('Month', inplace=True)
#check datatype of index
Maji.index
# Out:
# DatetimeIndex(['2014-03-31', '2014-04-30', '2014-07-14', '2014-07-01',
#                '2014-07-31', '2014-09-03', '2014-11-11', '2014-12-09',
#                '2014-12-31', '2015-02-19', '2015-03-16', '2015-04-13',
#                '2015-08-12', '2015-09-10', '2015-08-31', '2015-10-08',
#                '2015-10-30', '2015-12-05', '2015-06-01', '2016-01-08',
#                '2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30', '2016-07-31', '2016-08-31',
#                '2016-09-30', '2016-10-31', '2016-11-30', '2016-12-31',
#                '2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
#                '2017-09-30', '2017-10-31', '2017-12-31', '2017-11-30',
#                '2018-01-31', '2018-04-30', '2018-07-31', '2018-06-30',
#                '2018-05-31', '2018-05-31', '2018-05-31', '2018-09-13',
# ...

# %%
#Data Preprocessing
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer
Encoder=preprocessing.LabelEncoder()
Maji2=Maji.apply(preprocessing.LabelEncoder().fit_transform)
print("labelled Path\n", Maji2)
print (Maji2)
# Out:
# labelled Path
#              Amount
# Month
# 2014-03-31      14
# 2014-04-30      30
# 2014-07-14       3
# 2014-07-01      13
# 2014-07-31      33
# ...            ...
# 2019-08-31      50
# 2019-10-15      58
# 2019-09-30      58
# 2019-10-31      52
# 2019-11-29      54
#
# [69 rows x 1 columns]
#             Amount
# Month
# 2014-03-31      14
# 2014-04-30      30
# 2014-07-14       3
# 2014-07-01      13
# 2014-07-31      33
# ...            ...
# 2019-08-31      50
# 2019-10-15      58
# 2019-09-30      58
# 2019-10-31      52
# 2019-11-29      54
#
# [69 rows x 1 columns]

# %%
#Lets convert the data type which is ‘datetime64[ns] to time series
#convert to time series:
ts = Maji2['Amount']
ts.head(10)
# Out:
# Month
# 2014-03-31    14
# 2014-04-30    30
# 2014-07-14     3
# 2014-07-01    13
# 2014-07-31    33
# 2014-09-03    19
# 2014-11-11    16
# 2014-12-09    26
# 2014-12-31     2
# 2015-02-19     6
# Name: Amount, dtype: int64

# %% [markdown]
# Let’s explore the various properties date-time based index:
#     ___________________________________________________________________________________

# %%
#1.Specify the index as a string constant
ts['2014-12-09']
# Out:
# Month
# 2014-12-09    26
# Name: Amount, dtype: int64

# %%
#2.Import the datetime library and use the 'datetime function':
from datetime import datetime
ts[datetime(2015,2,19)]
# Out:
# 6

# %%
#Get range
#1.Specify the entire range
ts['2015-01-01':'2016-05-01']
# Out:
# Month
# 2015-02-19     6
# 2015-03-16    38
# 2015-04-13    28
# 2015-08-12    42
# 2015-09-10    15
# 2015-08-31    27
# 2015-10-08    32
# 2015-10-30    63
# 2015-12-05    53
# 2015-06-01    10
# 2016-01-08    49
# 2016-01-31    17
# 2016-02-29    64
# 2016-03-31    61
# 2016-04-30    60
# Name: Amount, dtype: int64

# %%
#Lets understand the stationerity of the data by:
plt.plot(ts)
# Out:
# /home/franc/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
ts.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Month', fontsize=20);

# %%
#Making the Month column to be the index
Maji.Month = pd.to_datetime(Maji.Month)
Maji.set_index('Month', inplace=True)
Maji.head()

# %%
#Data Preprocessing
from sklearn import preprocessing
from sklearn.preprocessing import Normalizer
Encoder=preprocessing.LabelEncoder()
Maji2=Maji.apply(preprocessing.LabelEncoder().fit_transform)
print("labelled Path\n", Maji)
print (Maji)

# %%
Maji2.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Year', fontsize=20);

# %%
Amount['2017':]

# %% [markdown]
# LINERA REGRESSION WITH SCIKIT-LEARN
# _____________________________________________________________________________

# %%
X = Stima2['Month'].values.reshape(-1,1)
y = Stima2['Amount'].values
